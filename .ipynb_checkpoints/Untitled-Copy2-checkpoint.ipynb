# %%
from model import BPR, FTD, HTD

from utils import train_dataset, test_dataset, evaluate, print_result, read_settings
from run import run_base, run_FTD, run_HTD
from copy import deepcopy
import time

import torch
import torch.utils.data as data
import torch.optim as optim

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# Setup
## gpu setting
gpu = torch.device('cuda:1')

## Hyperparameters for Training
lr, batch_size = 0.001, 1024
reg = 0.001

## Load dataset
user_num, item_num = 5220, 25182

train_R, train_interactions, valid_R, test_R = read_settings()
train_dataset = train_dataset(user_num, item_num, train_R, train_interactions)
test_dataset = test_dataset(user_num, item_num, valid_R, test_R)
train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

run_dict = {'train_loader':train_loader, 'test_dataset':test_dataset, 'lr':lr, 'reg':reg, 'gpu':gpu, \
            'early_stop':5, 'eval_period':4}

# %%
## Generate Teacher model
model = BPR(user_num, item_num, dim=200, gpu=gpu).to(gpu)
Teacher_history = run_base(run_dict, model)
# Out:
#  35%|███▌      | 176/500 [09:36<17:40,  3.27s/it]

# %%
## Generate Student model
model = BPR(user_num, item_num, dim=10, gpu=gpu).to(gpu)
Student_history = run_base(run_dict, model)
# Out:
#  38%|███▊      | 192/500 [09:50<15:46,  3.07s/it]

# %%
## Load Trained Teacher
Teacher = BPR(user_num, item_num, dim=200, gpu=gpu)
with torch.no_grad():
    model_path = "./saved_models/200"
    Teacher = Teacher.to(gpu)
    Teacher.load_state_dict(torch.load(model_path))
    Teacher_user_emb, Teacher_item_emb = Teacher.get_embedding()
    del Teacher

run_dict['lmbda_TD'] = 0.001
model = FTD(user_num, item_num, Teacher_user_emb, Teacher_item_emb, gpu=gpu, student_dim=10).to(gpu)
FTD_history = run_FTD(run_dict, model)
# Out:
#   6%|▌         | 28/500 [01:53<31:50,  4.05s/it]

# %%
## Load Trained Teacher
Teacher = BPR(user_num, item_num, dim=200, gpu=gpu)
with torch.no_grad():
    model_path = "./saved_models/200"
    Teacher = Teacher.to(gpu)
    Teacher.load_state_dict(torch.load(model_path))
    Teacher_user_emb, Teacher_item_emb = Teacher.get_embedding()
    del Teacher

K = 30
design_choice = 'second'
run_dict['alpha'] = 0.5
model = HTD(user_num, item_num, Teacher_user_emb, Teacher_item_emb, gpu=gpu, student_dim=10, K=K, choice=design_choice).to(gpu)
HTD_history = run_HTD(run_dict, model)
# Out:
#  18%|█▊        | 88/500 [19:33<1:31:31, 13.33s/it]

# %%
## Load Trained Teacher
Teacher = BPR(user_num, item_num, dim=200, gpu=gpu)
with torch.no_grad():
    model_path = "./saved_models/200"
    Teacher = Teacher.to(gpu)
    Teacher.load_state_dict(torch.load(model_path))
    Teacher_user_emb, Teacher_item_emb = Teacher.get_embedding()
    del Teacher

K = 30
design_choice = 'second'
run_dict['alpha'] = 0.
model = HTD(user_num, item_num, Teacher_user_emb, Teacher_item_emb, gpu=gpu, student_dim=10, K=K, choice=design_choice).to(gpu)
HTD_history2 = run_HTD(run_dict, model)
# Out:
#  48%|████▊     | 240/500 [53:02<57:27, 13.26s/it]

# %%
epoch = 100

#plt.plot([i for i in range(epoch)], Teacher_history[:epoch], label='Teacher')

tmp = Student_history[:]
tmp = tmp[:min(epoch // 4, len(tmp))] + tmp[-1] * (epoch // 4 - len(tmp))
plt.plot([i * 4 for i in range(0, epoch, 4)], tmp, label='Student')

tmp = FTD_history[:]
tmp = tmp[:min(epoch // 4, len(tmp))] + tmp[-1] * (epoch // 4 - len(tmp))
plt.plot([i * 4 for i in range(0, epoch, 4)], tmp, label='FTD')

tmp = HTD_history[:]
tmp = tmp[:min(epoch // 4, len(tmp))] + tmp[-1] * (epoch // 4 - len(tmp))
plt.plot([i * 4 for i in range(0, epoch, 4)], tmp, label='HTD')


plt.legend(loc=4, fontsize=17)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5013b336db25> in <module>
#       9 tmp = FTD_history[:]
#      10 tmp = tmp[:min(epoch // 4, len(tmp))] + tmp[-1] * (epoch // 4 - len(tmp))
# ---> 11 plt.plot([i * 4 for i in range(0, epoch, 4)], tmp, label='FTD')
#      12
#      13 tmp = HTD_history[:]
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/anaconda3/envs/torch/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (25,) and (7,)
