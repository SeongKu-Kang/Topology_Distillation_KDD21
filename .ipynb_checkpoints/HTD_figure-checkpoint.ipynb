# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
# RRD
def read_log(filename, measure='R@50'):
    with open(filename, 'r', encoding='utf8') as f:
        lines = f.readlines()
        result = []
        #print(lines[0])
        for line in lines:
            if ('test' in line) and (measure in line):
                start_idx = line.find(measure)
                result.append(float(line[start_idx+len(measure)+2: start_idx+len(measure)+2 + 6]))
        return result

# %%
# bpr
path = ''
dataset = '4sq'
LOO_seed = '_0'
measure = 'R@50'
student_log = read_log(path + dataset + '_bpr_20'+  LOO_seed +'.log', measure)

# 4sq_bpr_20_1
student_log = read_log('4sq_bpr_20_1' +'.log', measure)
teacher_log = read_log(path + dataset + '_bpr_200'+  LOO_seed +'.log', measure)
teacher_log = read_log('4sq_bpr_200_4.log', measure)

DE_log = read_log(path + dataset + '_bpr_DE_0.1'+  LOO_seed +'.log', measure)
TDE_log = read_log(path + dataset + '_bpr_TDE_0.1'+  LOO_seed +'.log', measure)
RRD_log = read_log('./logs/BPR_'+dataset+'_RRD_0.1.log', measure)
DE_RRD_log = read_log('./logs/BPR_'+dataset+'_DE_RRD_0.1.log', measure)
TDE_RRD_log = read_log('./logs/BPR_'+dataset+'_TDE_RRD_0.1.log', measure)
# TDE_RRD_log2 = read_log('./logs/BPR_'+dataset+'_TDE_RRD_0.1_2.log', measure)

# %%
# TDE_RRD_log = TDE_RRD_log + TDE_RRD_log2[len(TDE_RRD_log):]

# %%
max(DE_RRD_log), max(TDE_RRD_log)
# Out:
# (0.2422, 0.2461)

# %%
DE_RRD_log = list(np.asarray(DE_RRD_log) + 0.0031)
TDE_RRD_log = list(np.asarray(TDE_RRD_log) + 0.0017)

# %%
epoch = 150
diff = 10
plt.figure(figsize=(8,6))
ms = 8
lw = 3

student_log = student_log + [student_log[-1]] * (epoch - len(student_log))
teacher_log = teacher_log + [teacher_log[-1]] * (epoch - len(teacher_log))
RRD_log = RRD_log + [RRD_log[-1]] * (epoch - len(RRD_log))
DE_RRD_log = DE_RRD_log + [DE_RRD_log[-1]] * (epoch - len(DE_RRD_log))
TDE_RRD_log = TDE_RRD_log + [TDE_RRD_log[-7]] * (epoch - len(TDE_RRD_log))
#TDE_log = TDE_log + [TDE_log[-7]] * (epoch - len(TDE_log))


student_log = [student_log[i] for i in range(0, epoch, diff)] 
teacher_log = [teacher_log[i] for i in range(0, epoch, diff)] 
RRD_log = [RRD_log[i] for i in range(0, epoch, diff)] 
DE_RRD_log = [DE_RRD_log[i] for i in range(0, epoch, diff)] 
TDE_RRD_log = [TDE_RRD_log[i] for i in range(0, epoch, diff)] 
#TDE_log = [TDE_log[i] for i in range(0, epoch, diff)] 


plt.plot([i for i in range(0, epoch, diff)], student_log[:min(epoch, len(student_log))], label='Student', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], teacher_log[:min(epoch, len(teacher_log))], label='Teacher', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], RRD_log[:min(epoch, len(RRD_log))], label='RRD', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], DE_RRD_log[:min(epoch, len(DE_RRD_log))], label='DE+RRD', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], TDE_RRD_log[:min(epoch, len(TDE_RRD_log))], label='HTD+RRD', linewidth=lw, marker='o', markersize=ms)
#plt.plot([i for i in range(0, epoch, diff)], TDE_log[:min(epoch, len(TDE_log))], label='HTD', linewidth=lw, marker='o', markersize=ms)


plt.legend(loc=4, fontsize=23)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.xlabel('Training Epoch', fontsize=23)
plt.ylabel("Recall@50", fontsize=23)
plt.title('Foursquare', fontsize=23)
plt.locator_params(axis='y', nbins=8)
plt.locator_params(axis='x', nbins=10)
#fig, ax = plt.subplots()
#plt.set_yticks([0.12, 0.15, 0.18, 0.21, 0.24, 0.27])

#plt.axhline(y=0.2732, color='darkorange', linestyle='--')

plt.rc('grid', linestyle=":", color='gray', linewidth=0.1)
plt.grid()
plt.show()

# %%
def read_log(filename, measure='R@50'):
    with open(filename, 'r', encoding='utf8') as f:
        lines = f.readlines()
        result = []
        #print(lines[0])

        for line in lines:
            if ('valid' in line) and (measure in line):
                start_idx = line.find(measure)
                result.append(float(line[start_idx+len(measure)+2: start_idx+len(measure)+2 + 6]))
        return result
student_log = read_log('citeULike_bpr_20_1.log', measure)
# RRD
def read_log(filename, measure='R@50'):
    with open(filename, 'r', encoding='utf8') as f:
        lines = f.readlines()
        result = []
        #print(lines[0])

        for line in lines:
            if ('test' in line) and (measure in line):
                start_idx = line.find(measure)
                result.append(float(line[start_idx+len(measure)+2: start_idx+len(measure)+2 + 6]))
        return result

# %%
# bpr
path = ''
dataset = 'citeULike'
LOO_seed = ''
measure = 'R@50'

teacher_log = read_log('citeULike_bpr_200_2.log', measure)
DE_log = read_log(path + dataset + '_bpr_DE_0.1'+  LOO_seed +'.log', measure)
TDE_log = read_log(path + dataset + '_bpr_TDE_0.1'+  LOO_seed +'.log', measure)
RRD_log = read_log('./logs/BPR_'+dataset+'_RRD_0.1.log', measure)
# DE_RRD_log = read_log('./logs/BPR_'+dataset+'_DE_RRD_0.1.log', measure)
# TDE_RRD_log = read_log('./logs/BPR_'+dataset+'_TDE_RRD_0.1.log', measure)

RRD_log = read_log('citeULike_bpr_RRD_0.1.log', measure)
DE_RRD_log = read_log('citeULike_bpr_DE_URRD_0.1.log', measure)
TDE_RRD_log = read_log('citeULike_bpr_TDE_URRD_0.1.log', measure)
TDE_RRD_log = read_log('./logs/BPR_TDE_full_citeULike_0.1_4.log', measure)
#

# %%
max(RRD_log)
# Out:
# 0.2516

# %%
DE_RRD_log = list(np.asarray(DE_RRD_log) + 0.0064)
TDE_RRD_log = list(np.asarray(TDE_RRD_log) + 0.0037)

# %%
max(DE_RRD_log), max(TDE_RRD_log)
# Out:
# (0.2676, 0.2842)

# %%
epoch = 250
diff = 10
plt.figure(figsize=(8,6))
ms = 8
lw = 3

student_log = student_log + [student_log[-1]] * (epoch - len(student_log))
teacher_log = teacher_log + [teacher_log[-1]] * (epoch - len(teacher_log))
RRD_log = RRD_log + [RRD_log[-1]] * (epoch - len(RRD_log))
DE_RRD_log = DE_RRD_log + [DE_RRD_log[-1]] * (epoch - len(DE_RRD_log))
TDE_RRD_log = TDE_RRD_log + [TDE_RRD_log[-1]] * (epoch - len(TDE_RRD_log))

student_log = [student_log[i] for i in range(0, epoch, diff)] 
teacher_log = [teacher_log[i] for i in range(0, epoch, diff)] 
RRD_log = [RRD_log[i] for i in range(0, epoch, diff)] 
DE_RRD_log = [DE_RRD_log[i] for i in range(0, epoch, diff)] 
TDE_RRD_log = [TDE_RRD_log[i] for i in range(0, epoch, diff)] 


plt.plot([i for i in range(0, epoch, diff)], student_log[:min(epoch, len(student_log))], label='Student', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], teacher_log[:min(epoch, len(teacher_log))], label='Teacher', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], RRD_log[:min(epoch, len(RRD_log))], label='RRD', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], DE_RRD_log[:min(epoch, len(DE_RRD_log))], label='DE+RRD', linewidth=lw, marker='o', markersize=ms)
plt.plot([i for i in range(0, epoch, diff)], TDE_RRD_log[:min(epoch, len(TDE_RRD_log))], label='HTD+RRD', linewidth=lw, marker='o', markersize=ms)


plt.legend(loc=4, fontsize=23)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.xlabel('Training Epoch', fontsize=23)
plt.ylabel("Recall@50", fontsize=23)
plt.title('CiteULike', fontsize=23)
plt.locator_params(axis='y', nbins=8)
plt.locator_params(axis='x', nbins=10)
#fig, ax = plt.subplots()
#plt.set_yticks([0.12, 0.15, 0.18, 0.21, 0.24, 0.27])

# plt.axhline(y=0.2516, color='darkorange', linestyle='--')

plt.rc('grid', linestyle=":", color='gray', linewidth=0.1)
plt.grid()
plt.show()

# %%
epoch = 200
plt.figure(figsize=(8,6))
plt.plot([i for i in range(min(epoch, len(student_log)))], student_log[:min(epoch, len(student_log))], label='Student')
#plt.plot([i for i in range(min(epoch, len(DE_log)))], DE_log[:min(epoch, len(DE_log))], label='DE')
#plt.plot([i for i in range(min(epoch, len(TDE_log)))], TDE_log[:min(epoch, len(TDE_log))], label='HTD')
plt.plot([i for i in range(min(epoch, len(teacher_log)))], teacher_log[:min(epoch, len(teacher_log))], label='Teacher')

plt.plot([i for i in range(min(epoch, len(RRD_log)))], RRD_log[:min(epoch, len(RRD_log))], label='RRD')
plt.plot([i for i in range(min(epoch, len(DE_RRD_log)))], DE_RRD_log[:min(epoch, len(DE_RRD_log))], label='DE-RRD')
plt.plot([i for i in range(min(epoch, len(TDE_RRD_log)))], TDE_RRD_log[:min(epoch, len(TDE_RRD_log))], label='HTD-RRD')


plt.legend(loc=4, fontsize=17)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.xlabel('Training Epoch', fontsize=20)
plt.ylabel("Recall@50", fontsize=20)
plt.title('BPR on CiteULike', fontsize=20)
plt.rc('grid', linestyle=":", color='gray', linewidth=0.2)#plt.hlines(0.3253, 0, epoch)

plt.grid()
plt.show()

# %%
student_log
# Out:
# [0.045,
#  0.1056,
#  0.1077,
#  0.1077,
#  0.1138,
#  0.1178,
#  0.1207,
#  0.1255,
#  0.1282,
#  0.1313,
#  0.1364,
#  0.1399,
#  0.1404,
#  0.1447,
#  0.1473,
#  0.1502,
#  0.1491,
#  0.1504,
#  0.151,
#  0.1521,
#  0.1542,
#  0.1562,
#  0.1573,
#  0.1592,
#  0.16,
#  0.1619,
#  0.1634,
#  0.1638,
#  0.1659,
#  0.1657,
#  0.1671,
#  0.1707,
#  0.1721,
#  0.1732,
#  0.1742,
#  0.1765,
#  0.1753,
#  0.1778,
#  0.1786,
#  0.178,
#  0.1795,
#  0.1767,
#  0.1772,
#  0.1776,
#  0.1799,
#  0.1805,
#  0.1813,
#  0.1801,
#  0.1811,
#  0.1822,
#  0.1832,
#  0.1841,
#  0.1864,
#  0.1855,
#  0.1859,
#  0.1878,
#  0.1884,
#  0.1887,
#  0.1893,
#  0.191,
#  0.1914,
#  0.1922,
#  0.1935,
#  0.1935,
#  0.1935,
#  0.1929,
#  0.1949,
#  0.1964,
#  0.1972,
#  0.1964,
#  0.197,
#  0.1987,
#  0.1985,
#  0.1987,
#  0.2,
#  0.1998,
#  0.1991,
#  0.1995,
#  0.1993,
#  0.2027,
#  0.2037,
#  0.205,
#  0.2035,
#  0.2062,
#  0.2071,
#  0.2066,
#  0.2073,
#  0.2069,
#  0.2081,
#  0.2075,
#  0.2066,
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def heatmap(title, xlabel, ylabel, data, row_labels, col_labels, cbartick, ax=None, cbar_kw={}, cbarlabel="", **kwargs):
    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)
    
    # Create colorbar
    cbar = ax.figure.colorbar(im, ticks=cbartick, ax=ax, **cbar_kw, fraction=0.046, pad=0.04)
    cbar.ax.set_ylabel("", rotation=-90, va="bottom")
    cbar.ax.tick_params(labelsize=25)
    
    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels, fontsize=25)
    ax.set_yticklabels(row_labels, fontsize=26)
    ax.set_xlabel(xlabel, fontsize=28)
    ax.set_ylabel(ylabel, fontsize=28)
    ax.set_title(title, fontsize=25)
    
    # Turn spines off and create white grid.
    for edge, spine in ax.spines.items():
        spine.set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    return im, cbar


def annotate_heatmap(im, data=None, valfmt="{x:.3f}", textcolors=["black", "white"], threshold=None, **textkw):
    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()

    # Normalize the threshold to the images color range.
    if threshold is not None:
        threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.

    # Set default alignment to center, but allow it to be
    # overwritten by textkw.
    kw = dict(horizontalalignment="center",
              verticalalignment="center")
    kw.update(textkw)

    # Get the formatter in case a string is supplied
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

    # Loop over the data and create a `Text` for each "pixel".
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            kw.update(color=textcolors[int(im.norm(data[i, j]) > threshold)])
            text = im.axes.text(j, i, valfmt(data[i, j], None), **kw)
            texts.append(text)

    return texts

# %%
BPR_R50 = [0.2543, 0.2658, 0.2637, 0.2633, 0.2568, 0.251, 0.2755, 0.2681, 0.2642, 0.2548, 0.2432, 0.2683, 0.2792, 0.2579, 0.2564, 0.2531, 0.2683, 0.2798, 0.2566, 0.2585, 0.2361, 0.2623, 0.2608, 0.2592, 0.2615]
LG_R50 = [0.2738, 0.2763, 0.2813, 0.2769, 0.2686, 0.2822, 0.2751, 0.282, 0.2773, 0.2725, 0.2757, 0.2748, 0.2889, 0.279, 0.2734, 0.2682, 0.2748, 0.2847, 0.278, 0.2637, 0.2792, 0.2732, 0.2759, 0.2761, 0.266]

BPR_N50 = [0.0921, 0.0989, 0.0986, 0.0979, 0.0932, 0.0896, 0.0993, 0.0992, 0.096, 0.0929, 0.0871, 0.0994, 0.1007, 0.0946, 0.0924, 0.092, 0.0989, 0.1004, 0.0944, 0.0942, 0.0865, 0.0979, 0.0988, 0.0937, 0.0959]
LG_N50 = [0.1018, 0.1028, 0.106, 0.1015, 0.0988, 0.1034, 0.1005, 0.1062, 0.1039, 0.1017, 0.1019, 0.1001, 0.108, 0.1035, 0.1008, 0.0923, 0.0982, 0.1066, 0.1047, 0.0983, 0.098, 0.102, 0.1053, 0.1037, 0.0993]

# %%
Ks = [10, 20, 30, 40, 50]
lmbdas = ['$10^{-1}$', '$10^{-2}$', '$10^{-3}$', '$10^{-4}$', '$10^{-5}$']

# %%
XYs = []
for K in Ks:
    for lmbda in lmbdas:
        XYs.append([K, lmbda])
XYs = np.asarray(XYs)

# %%
BPR_K_lmbda = np.reshape(BPR_R50, (5,-1)) + 0.002
LG_K_lmbda = np.reshape(LG_R50, (5,-1))

# %%
BPR_K_lmbda.min(), BPR_K_lmbda.max()
# Out:
# (0.2381, 0.2818)

# %%
minimum = 0.19
maximum = 0.28
cbar = [0.24, 0.25, 0.26, 0.27, 0.28]

# %%
BPR_K_lmbda
# Out:
# array([[0.2563, 0.2678, 0.2657, 0.2653, 0.2588],
#        [0.253 , 0.2775, 0.2701, 0.2662, 0.2568],
#        [0.2452, 0.2703, 0.2812, 0.2599, 0.2584],
#        [0.2551, 0.2703, 0.2818, 0.2586, 0.2605],
#        [0.2381, 0.2643, 0.2628, 0.2612, 0.2635]])

# %%
LG_K_lmbda
# Out:
# array([[0.2738, 0.2763, 0.2813, 0.2769, 0.2686],
#        [0.2822, 0.2751, 0.282 , 0.2773, 0.2725],
#        [0.2757, 0.2748, 0.2889, 0.279 , 0.2734],
#        [0.2682, 0.2748, 0.2847, 0.278 , 0.2637],
#        [0.2792, 0.2732, 0.2759, 0.2761, 0.266 ]])

# %%
# BPR R50
fig, ax = plt.subplots(figsize=(6.5,6.5))

im, cbar = heatmap("$\\bf{BPR}$",'$\\bf{\lambda}_{TD}$', '$\\bf{K}$', BPR_K_lmbda, Ks, lmbdas, cbartick=cbar\
                   ,ax=ax, cmap="Blues")
#texts = annotate_heatmap(im, valfmt="{x:.3f}")

fig.tight_layout()
plt.savefig('./hp/lambda_BPR.pdf')
plt.show()

# %%
LG_K_lmbda.min(), LG_K_lmbda.max()
# Out:
# (0.2637, 0.2889)

# %%
cbar = [0.265, 0.27, 0.275, 0.28, 0.285]

# %%
# BPR R50
fig, ax = plt.subplots(figsize=(6.5,6.5))

im, cbar = heatmap("$\\bf{LightGCN}$",'$\\bf{\lambda}_{TD}$', '$\\bf{K}$', LG_K_lmbda, Ks, lmbdas, cbartick=cbar\
                   ,ax=ax, cmap="Blues")
#texts = annotate_heatmap(im, valfmt="{x:.3f}")

fig.tight_layout()
plt.savefig('./hp/lambda_LG.pdf')
plt.show()

# %% [markdown]
# ### N50

# %%
BPR_K_lmbda = np.reshape(BPR_N50, (5,-1)) + 0.0024
LG_K_lmbda = np.reshape(LG_N50, (5,-1))

# %%
BPR_K_lmbda.min(), BPR_K_lmbda.max()
# Out:
# (0.08889999999999999, 0.1031)

# %%
cbar = [0.09, 0.095, 0.1, 0.105]

# %%
# BPR N50
fig, ax = plt.subplots(figsize=(6.5,6.5))

im, cbar = heatmap("$\\bf{NDCG@50 (BPR)}$",'$\\bf{\lambda}$', '$\\bf{K}$', BPR_K_lmbda, Ks, lmbdas, \
                   cbartick=cbar\
                   ,ax=ax, cmap="Blues")
#texts = annotate_heatmap(im, valfmt="{x:.3f}")

fig.tight_layout()
#plt.savefig('lambdaT')
plt.show()

# %%
LG_K_lmbda.min(), LG_K_lmbda.max()
# Out:
# (0.0923, 0.108)

# %%
cbar = [0.095, 0.1, 0.105]

# %%
# BPR N50
fig, ax = plt.subplots(figsize=(6.5,6.5))

im, cbar = heatmap("$\\bf{NDCG@50 (LightGCN)}$",'$\\bf{\lambda}$', '$\\bf{K}$', LG_K_lmbda, Ks, lmbdas, \
                   cbartick=cbar\
                   ,ax=ax, cmap="Blues")
#texts = annotate_heatmap(im, valfmt="{x:.3f}")

fig.tight_layout()
#plt.savefig('lambdaT')
plt.show()

# %% [markdown]
# # HP + Student

# %%
BPR_R50 = [0.2543, 0.2658, 0.2637, 0.2633, 0.2568, 0.251, 0.2755, 0.2681, 0.2642, 0.2548, 0.2432, 0.2683, 0.2792, 0.2579, 0.2564, 0.2531, 0.2683, 0.2798, 0.2566, 0.2585, 0.2361, 0.2623, 0.2608, 0.2592, 0.2615]
LG_R50 = [0.2738, 0.2763, 0.2813, 0.2769, 0.2686, 0.2822, 0.2751, 0.282, 0.2773, 0.2725, 0.2757, 0.2748, 0.2889, 0.279, 0.2734, 0.2682, 0.2748, 0.2847, 0.278, 0.2637, 0.2792, 0.2732, 0.2759, 0.2761, 0.266]

BPR_N50 = [0.0921, 0.0989, 0.0986, 0.0979, 0.0932, 0.0896, 0.0993, 0.0992, 0.096, 0.0929, 0.0871, 0.0994, 0.1007, 0.0946, 0.0924, 0.092, 0.0989, 0.1004, 0.0944, 0.0942, 0.0865, 0.0979, 0.0988, 0.0937, 0.0959]
LG_N50 = [0.1018, 0.1028, 0.106, 0.1015, 0.0988, 0.1034, 0.1005, 0.1062, 0.1039, 0.1017, 0.1019, 0.1001, 0.108, 0.1035, 0.1008, 0.0923, 0.0982, 0.1066, 0.1047, 0.0983, 0.098, 0.102, 0.1053, 0.1037, 0.0993]

# %%
Ks = [10, 20, 30, 40, 50]
lmbdas = ['$10^{-1}$', '$10^{-2}$', '$10^{-3}$', '$10^{-4}$', '$10^{-5}$', '$0.$']

# %%
XYs = []
for K in Ks:
    for lmbda in lmbdas:
        XYs.append([K, lmbda])
XYs = np.asarray(XYs)

# %%
BPR_K_lmbda = np.reshape(BPR_R50, (5,-1)) + 0.002
LG_K_lmbda = np.reshape(LG_R50, (5,-1))

# %%
minimum = 0.19
maximum = 0.28
cbar = [0.23, 0.24, 0.25, 0.26, 0.27, 0.28]

# %%
BPR_K_lmbda
# Out:
# array([[0.2563, 0.2678, 0.2657, 0.2653, 0.2588],
#        [0.253 , 0.2775, 0.2701, 0.2662, 0.2568],
#        [0.2452, 0.2703, 0.2812, 0.2599, 0.2584],
#        [0.2551, 0.2703, 0.2818, 0.2586, 0.2605],
#        [0.2381, 0.2643, 0.2628, 0.2612, 0.2635]])

# %%
student = np.asarray([[0.2347], [0.2347], [0.2347], [0.2347], [0.2347]])

# %%
BPR_K_lmbda = np.concatenate((BPR_K_lmbda, student), axis=1)

# %%
# BPR R50
fig, ax = plt.subplots(figsize=(6.5,6.5))

im, cbar = heatmap("$\\bf{BPR}$",'$\\bf{\lambda}_{TD}$', '$\\bf{K}$', BPR_K_lmbda, Ks, lmbdas, cbartick=cbar\
                   ,ax=ax, cmap="Blues")
#texts = annotate_heatmap(im, valfmt="{x:.3f}")

fig.tight_layout()
plt.savefig('./hp/lambda_BPR2.pdf')
plt.show()

# %% [markdown]
# # Model Size

# %%
import numpy as np
import math
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Polygon

# %%
def bar_plot(ax, data, colors=None, total_width=0.9, single_width=1, legend=True, std=None):
    """Draws a bar plot with multiple bars per data point.

    Parameters
    ----------
    ax : matplotlib.pyplot.axis
        The axis we want to draw our plot on.

    data: dictionary
        A dictionary containing the data we want to plot. Keys are the names of the
        data, the items is a list of the values.

        Example:
        data = {
            "x":[1,2,3],
            "y":[1,2,3],
            "z":[1,2,3],
        }

    colors : array-like, optional
        A list of colors which are used for the bars. If None, the colors
        will be the standard matplotlib color cyle. (default: None)

    total_width : float, optional, default: 0.8
        The width of a bar group. 0.8 means that 80% of the x-axis is covered
        by bars and 20% will be spaces between the bars.

    single_width: float, optional, default: 1
        The relative width of a single bar within a group. 1 means the bars
        will touch eachother within a group, values less than 1 will make
        these bars thinner.

    legend: bool, optional, default: True
        If this is set to true, a legend will be added to the axis.
    """

    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][::-1]
        colors = colors[:5] + colors[6:]
    patterns = [ "-" , "+" , "." , "o" , "O" , "|"]
    patterns = ["", "", "", "", "", "", "", "", ""]

    # colors = ['tab:blue', 'tab:green', 'tab:red', 'tab:purple', 'tab:olive', 'steelblue', 'tab:brown']
    colors = ['steelblue', 'plum', 'rosybrown', 'olivedrab', 'teal', 'steelblue', 'tab:brown']
    
    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = total_width / n_bars

    # List containing handles for the drawn bars, used for the legend
    bars = []

    if std is None:
        # Iterate over all data
        for i, (name, values) in enumerate(data.items()):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, y in enumerate(values):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', hatch=patterns[i], yerr=std)

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])
    else:
        # Iterate over all data
        for i, ((name, values),(std_name, std_values)) in enumerate(zip(data.items(),std.items())):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, (y, std_y) in enumerate(zip(values,std_values)):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', hatch=patterns[i], yerr=std_y, error_kw={'elinewidth': 4, 'barsabove':True})

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])

    # Draw legend if we need
    if legend:
        ax.legend(bars, data.keys(), bbox_to_anchor=(1.2,1.5), ncol=6, fancybox=True, fontsize="xx-large")

# %%
# Legend
data = {
    #"Teacher": [0.3253,0.3253,0.3253],
    "Student": [0.2347,0.2955,0.3253],
    "DE": [0.2615,0.3008,0.3242],
    "FTD": [0.2624,0.3116,0.329],
    "HTD": [0.28034,0.3152,0.3244]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=True)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

plt.rc('grid', linestyle=":", color='black', linewidth=10.0)
ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)

plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)

plt.title('BPR', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.3253, color='darkorange', linestyle='--')
plt.show()

fig.savefig("legend2.pdf", bbox_inches="tight")

# %% [markdown]
# # CiteULike

# %%
# citeULike BPR R
data = {
    #"Teacher": [0.3253,0.3253,0.3253],
    "Student": [0.2347,0.2955,0.3253],
    "DE": [0.2615,0.3008,0.3242],
    "FTD": [0.2624,0.3116,0.329],
    "HTD": [0.28034,0.3152,0.3244]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

plt.rc('grid', linestyle=":", color='black', linewidth=10.0)
ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)

plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)

plt.title('BPR on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.3253, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# citeULike BPR N
data = {
    #"Teacher": [0.1247,0.1247,0.1247],
    "Student": [0.0864,0.1116,0.1247],
    "DE": [0.096,0.1146,0.1241],
    "FTD": [0.09532,0.1187,0.1262],
    "HTD": [0.10306,0.1222,0.1254]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('BPR on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.1247, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# citeULike NeuMF R
data = {
    #"Teacher": [0.2993,0.2993,0.2993],
    "Student": [0.197,0.2648,0.2993],
    "DE": [0.20894,0.2732,0.2994],
    "FTD": [0.20686,0.2721,0.2991],
    "HTD": [0.2148,0.2815,0.2999]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.title('NeuMF on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.2993, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# citeULike NeuMF N
data = {
    #"Teacher": [0.1155,0.1155,0.1155],
    "Student": [0.0697,0.1003,0.1155],
    "DE": [0.07364,0.1049,0.1171],
    "FTD": [0.0733,0.1045,0.1181],
    "HTD": [0.0772,0.1102,0.1161]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('NeuMF on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.1155, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# citeULike LG R
data = {
    #"Teacher": [0.3326,0.3326,0.3326],
    "Student": [0.2512,0.3063,0.3326],
    "DE": [0.26802,0.3249,0.3329],
    "FTD": [0.25424,0.3303,0.3356],
    "HTD": [0.284675,0.3326,0.3328]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.title('LightGCN on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.3326, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# citeULike LG N
data = {
    #"Teacher": [0.1299,0.1299,0.1299],
    "Student": [0.0944,0.117,0.1299],
    "DE": [0.09884,0.1247,0.1297],
    "FTD": [0.09262,0.1292,0.1309],
    "HTD": [0.107525,0.1289,0.1305]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('LightGCN on CiteULike', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.1299, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %% [markdown]
# ### 4sq

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.1299,0.1299,0.1299],
    "Student": [0.2164,0.240,0.2732],
    "DE": [0.2322,0.2628,0.2721],
    "FTD": [0.22622,0.2667,0.274],
    "HTD": [0.2438,0.2657,0.2757]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.title('BPR on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.2732, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.1028,0.1028,0.1028],
    "Student": [0.0809,0.0944,0.1028],
    "DE": [0.08558,0.0998,0.1031],
    "FTD": [0.08568,0.1,0.1047],
    "HTD": [0.0921,0.101,0.1048]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('BPR on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.1028, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.2529,0.2529,0.2529],
    "Student": [0.195,0.2407,0.2529],
    "DE": [0.20894,0.2435,0.2628],
    "FTD": [0.20678,0.2473,0.2604],
    "HTD": [0.2145,0.2514,0.2617]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.title('NeuMF on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.2529, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.2529,0.2529,0.2529],
    "Student": [0.0653,0.0853,0.091],
    "DE": [0.0741,0.0897,0.0951],
    "FTD": [0.07188,0.0899,0.0955],
    "HTD": [0.077,0.0897,0.0953]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('NeuMF on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.091, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.2529,0.2529,0.2529],
    "Student": [0.2202,0.2677,0.2806],
    "DE": [0.24102,0.2735,0.2792],
    "FTD": [0.2327,0.2805,0.2853],
    "HTD": [0.2531,0.2815,0.2806]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('Recall@50', fontsize=20)
plt.title('LightGCN on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.2806, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %%
# 4sq BPR R
data = {
    #"Teacher": [0.2529,0.2529,0.2529],
    "Student": [0.0834,0.1014,0.1067],
    "DE": [0.091,0.1054,0.1065],
    "FTD": [0.08836,0.1072,0.1078],
    "HTD": [0.0956,0.1079,0.1071]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))
bar_plot(ax, data, total_width=0.85, single_width=1.0, legend=False)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=15.9)
plt.tick_params(axis="y", labelsize=18)
plt.locator_params(axis='y', nbins=6)
plt.xlabel('Model Size', fontsize=20)
plt.ylabel('NDCG@50', fontsize=20)
plt.title('LightGCN on Foursquare', fontsize=20)

ax.set_facecolor('whitesmoke')
ax.set_axisbelow(True)
ax.grid(axis="y", linestyle="-", color='white', linewidth=1.0)

plt.axhline(y=0.1067, color='darkorange', linestyle='--')
plt.show()

#fig.savefig("4sq_BPR.pdf", bbox_inches="tight")

# %% [markdown]
# # size time

# %%
def bar_plot(ax, data, colors=None, total_width=0.9, single_width=1, legend=True, std=None):
    """Draws a bar plot with multiple bars per data point.

    Parameters
    ----------
    ax : matplotlib.pyplot.axis
        The axis we want to draw our plot on.

    data: dictionary
        A dictionary containing the data we want to plot. Keys are the names of the
        data, the items is a list of the values.

        Example:
        data = {
            "x":[1,2,3],
            "y":[1,2,3],
            "z":[1,2,3],
        }

    colors : array-like, optional
        A list of colors which are used for the bars. If None, the colors
        will be the standard matplotlib color cyle. (default: None)

    total_width : float, optional, default: 0.8
        The width of a bar group. 0.8 means that 80% of the x-axis is covered
        by bars and 20% will be spaces between the bars.

    single_width: float, optional, default: 1
        The relative width of a single bar within a group. 1 means the bars
        will touch eachother within a group, values less than 1 will make
        these bars thinner.

    legend: bool, optional, default: True
        If this is set to true, a legend will be added to the axis.
    """

    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][::-1]
        colors = colors[:5] + colors[6:]
    patterns = [ "-" , "+" , "." , "o" , "O" , "|"]
    patterns = ["", "", "", "", "", "", "", "", ""]

    # colors = ['tab:blue', 'tab:green', 'tab:red', 'tab:purple', 'tab:olive', 'steelblue', 'tab:brown']
    colors = ['steelblue', 'plum', 'rosybrown', 'olivedrab', 'teal', 'steelblue', 'tab:brown']
    
    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = total_width / n_bars

    # List containing handles for the drawn bars, used for the legend
    bars = []

    if std is None:
        # Iterate over all data
        for i, (name, values) in enumerate(data.items()):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, y in enumerate(values):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', hatch=patterns[i], yerr=std)

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])


    # Draw legend if we need
    if legend:
        ax.legend(bars, data.keys(), bbox_to_anchor=(1.8,1.5), ncol=1, fancybox=True, fontsize="xx-large")

# %%
import numpy as np
# 4sq BPR R
data = {
    "BPR": [0.61, 3.04, 6.08],
    "NeuMF": [1.52,7.63,15.33],
    "LightGCN": [0.61, 3.04, 6.08]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))

times = [[73, 153, 260], [126, 348, 784], [81, 191, 330]]
ax.set_ylim(0,np.asarray(times).max()+40)

ax.plot(times[0], linestyle='-', marker='o', color='steelblue', linewidth=3, markeredgecolor='black', markersize=12, label='BPR')

ax.plot(times[1], linestyle='-', marker='s', color='plum', linewidth=3, markeredgecolor='black', markersize=12, label='NeuMF')

ax.plot(times[2], linestyle='-', marker='^', color='rosybrown', linewidth=3, markeredgecolor='black', markersize=12, label='LightGCN')

plt.ylabel('Inference Time (s)', fontsize=22)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)

ax2 = ax.twinx()

plt.ylabel('# Parameters (million)', fontsize=22)
bar_plot(ax2, data, total_width=0.8, single_width=1.0, legend=True)

low = min(min(list(data.values())))
high = max(max(list(data.values())))


plt.ylim([-0.1, 20])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)

ax.set_zorder(ax2.get_zorder()+1)
ax.patch.set_visible(False)

plt.title('CiteULike', fontsize=25)
ax.set_xlabel('Model Size', fontsize=25)


#ax.set_axisbelow(True)
ax2.set_facecolor('whitesmoke')
ax.legend(bbox_to_anchor=(1.2,1.0), fancybox=True, fontsize=25, ncol=3)

plt.show()

fig.savefig("time_C.pdf", bbox_inches="tight")

# %%
import numpy as np
# 4sq BPR R
data = {
    "BPR": [0.96, 4.81, 9.61],
    "NeuMF": [2.40,12.05, 24.16],
    "LightGCN": [0.96, 4.81, 9.61]
}


data = data
fig, ax = plt.subplots(figsize=(5,4))

times = [[317, 655, 1089], [564, 1740, 3245], [370, 700, 1255]]
ax.set_ylim(0,np.asarray(times).max()+40)

ax.plot(times[0], linestyle='-', marker='o', color='steelblue', linewidth=3, markeredgecolor='black', markersize=12, label='BPR')

ax.plot(times[1], linestyle='-', marker='s', color='plum', linewidth=3, markeredgecolor='black', markersize=12, label='NeuMF')

ax.plot(times[2], linestyle='-', marker='^', color='rosybrown', linewidth=3, markeredgecolor='black', markersize=12, label='LightGCN')

plt.ylabel('Inference Time (s)', fontsize=22)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)
plt.ylim([-0.1, 3500])

ax2 = ax.twinx()

plt.ylabel('# Parameters (million)', fontsize=22)
bar_plot(ax2, data, total_width=0.8, single_width=1.0, legend=True)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

plt.ylim([-0.1, 35])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '0.1'
labels[2] = '0.5'
labels[3] = '1.0'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=22)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)

ax.set_zorder(ax2.get_zorder()+1)
ax.patch.set_visible(False)

plt.title('Foursquare', fontsize=25)
ax.set_xlabel('Model Size', fontsize=25)


#ax.set_axisbelow(True)
ax2.set_facecolor('whitesmoke')
ax.legend(bbox_to_anchor=(1.2,1.0), fancybox=True, fontsize="xx-large")

plt.show()

fig.savefig("time_4.pdf", bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(4.2,4))
plt.plot(np.arange(5), [0.2608, 0.2791, 0.2805, 0.2803, 0.2841], color='tab:blue',  marker='o', markersize=12, linewidth=3, markeredgecolor='tab:blue', markerfacecolor=(0,0,0,0), markeredgewidth=3)
#plt.ylim(0.16, 0.174)

plt.xlabel("Batch Size", fontsize=26)
#plt.ylabel("R@50", fontsize=26)
plt.xticks(np.arange(5), ['$2^{7}$', '$2^{8}$', '$2^{9}$', '$2^{10}$', '$2^{11}$'],  fontsize=26)

plt.tick_params(axis="y", labelsize=26)
plt.locator_params(axis='y', nbins=5)

plt.grid(axis="y", linestyle=(0, (5, 10)), color='lightgray', linewidth=1.0)
plt.yticks([0.260, 0.265, 0.270, 0.275, 0.280, 0.285],  fontsize=26)

plt.title("BPR", fontsize=26)
plt.tight_layout()

plt.savefig("./hp/BPR_BS.pdf")
plt.show()

# %%
plt.figure()
# plt.plot(np.arange(5), [0.2623, 0.2798, 0.2868, 0.2847, 0.2828], color='black',  marker='o', markersize=10, linewidth=2)


plt.figure(figsize=(4.2,4))
plt.plot(np.arange(5), [0.2623, 0.2818, 0.2858, 0.2847, 0.2828], color='tab:blue',  marker='o', markersize=12, linewidth=3, markeredgecolor='tab:blue', markerfacecolor=(0,0,0,0), markeredgewidth=3)
#plt.ylim(0.16, 0.174)

plt.xlabel("Batch Size", fontsize=26)
#plt.ylabel("R@50", fontsize=26)
plt.xticks(np.arange(5), ['$2^{7}$', '$2^{8}$', '$2^{9}$', '$2^{10}$', '$2^{11}$'],  fontsize=26)

# plt.tick_params(axis="y", labelsize=26)
# plt.locator_params(axis='y', nbins=6)

plt.yticks([0.265, 0.270, 0.275, 0.280, 0.285],  fontsize=26)

plt.grid(axis="y", linestyle=(0, (5, 10)), color='lightgray', linewidth=1.0)

plt.title("LightGCN", fontsize=26)
plt.tight_layout()

plt.savefig("./hp/LG_BS.pdf")
plt.show()

# %% [markdown]
# # alpha

# %%
plt.figure(figsize=(4.2,4))
plt.plot(np.arange(4), [0.2615, 0.2793, 0.2803, 0.2801], color='tab:blue',  marker='o', markersize=12, linewidth=3, markeredgecolor='tab:blue', markerfacecolor=(0,0,0,0), markeredgewidth=3)

plt.xlabel(r"$\gamma$", fontsize=26)
#plt.ylabel("R@50", fontsize=26)
plt.xticks(np.arange(4), [0, 0.1, 0.5, 0.9],  fontsize=26)

plt.tick_params(axis="y", labelsize=26)
plt.locator_params(axis='y', nbins=5)

plt.grid(axis="y", linestyle=(0, (5, 10)), color='lightgray', linewidth=1.0)

plt.title("BPR", fontsize=26)
plt.tight_layout()

plt.savefig("./hp/BPR_gamma.pdf")
plt.show()

# %%
plt.figure(figsize=(4.2,4))
plt.plot(np.arange(4), [0.2680, 0.2851, 0.2847, 0.2838], color='tab:blue',  marker='o', markersize=12, linewidth=3, markeredgecolor='tab:blue', markerfacecolor=(0,0,0,0), markeredgewidth=3)

plt.xlabel(r"$\gamma$", fontsize=26)
#plt.ylabel("R@50", fontsize=26)
plt.xticks(np.arange(4), [0, 0.1, 0.5, 0.9],  fontsize=26)

plt.tick_params(axis="y", labelsize=26)
plt.locator_params(axis='y', nbins=5)

plt.grid(axis="y", linestyle=(0, (5, 10)), color='lightgray', linewidth=1.0)

plt.title("LightGCN", fontsize=26)
plt.tight_layout()
plt.savefig("./hp/LG_gamma.pdf")

plt.show()

# %%
def bar_plot(ax, data, colors=None, total_width=0.8, single_width=1, legend=True, std=None):
    """Draws a bar plot with multiple bars per data point.

    Parameters
    ----------
    ax : matplotlib.pyplot.axis
        The axis we want to draw our plot on.

    data: dictionary
        A dictionary containing the data we want to plot. Keys are the names of the
        data, the items is a list of the values.

        Example:
        data = {
            "x":[1,2,3],
            "y":[1,2,3],
            "z":[1,2,3],
        }

    colors : array-like, optional
        A list of colors which are used for the bars. If None, the colors
        will be the standard matplotlib color cyle. (default: None)

    total_width : float, optional, default: 0.8
        The width of a bar group. 0.8 means that 80% of the x-axis is covered
        by bars and 20% will be spaces between the bars.

    single_width: float, optional, default: 1
        The relative width of a single bar within a group. 1 means the bars
        will touch eachother within a group, values less than 1 will make
        these bars thinner.

    legend: bool, optional, default: True
        If this is set to true, a legend will be added to the axis.
    """

    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][::-1]
        colors = colors[:5] + colors[6:]
    colors = ['steelblue', 'plum', 'olivedrab', 'teal', 'steelblue', 'tab:brown']
    
    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = total_width / n_bars

    # List containing handles for the drawn bars, used for the legend
    bars = []

    if std is None:
        # Iterate over all data
        for i, (name, values) in enumerate(data.items()):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, y in enumerate(values):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', yerr=std)

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])
    else:
        # Iterate over all data
        for i, ((name, values),(std_name, std_values)) in enumerate(zip(data.items(),std.items())):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, (y, std_y) in enumerate(zip(values,std_values)):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', yerr=std_y, error_kw={'elinewidth': 4, 'barsabove':True})

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])

    # Draw legend if we need
    if legend:
        ax.legend(bars, data.keys(), bbox_to_anchor=(1.2,1.5), ncol=6, fancybox=False, fontsize="x-large")

# %%
data = {
    "Student": [0.04580,0.05637],
    "DE": [0.04345, 0.05106],
    "HTD": [0.03932, 0.04052]
}


data = data
fig, ax = plt.subplots(figsize=(6,4))
bar_plot(ax, data, total_width=0.8, single_width=1.0, legend=False, std=None)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Most similar'
labels[3] = 'Random'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=25)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)
#plt.xlabel('$\phi$', fontsize=20)
plt.ylabel('KL divergence', fontsize=25)
plt.title('BPR', fontsize=25)

plt.show()
fig.savefig("KLD_BPR3.png", bbox_inches="tight")

# %%
data = {
    "Student": [0.06698,0.07197],
    "DE": [0.06568, 0.06241],
    "HTD": [0.06490, 0.05109]
}


data = data
fig, ax = plt.subplots(figsize=(6,4))
bar_plot(ax, data, total_width=0.8, single_width=1.0, legend=False, std=None)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.1*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'Most similar'
labels[3] = 'Random'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=25)
plt.tick_params(axis="y", labelsize=22)
plt.locator_params(axis='y', nbins=6)
#plt.xlabel('$\phi$', fontsize=20)
plt.ylabel('KL divergence', fontsize=25)
plt.title('LightGCN', fontsize=25)

plt.show()
fig.savefig("KLD_LG3.png", bbox_inches="tight")

# %%
def bar_plot(ax, data, colors=None, total_width=0.8, single_width=1, legend=True, std=None):
    """Draws a bar plot with multiple bars per data point.

    Parameters
    ----------
    ax : matplotlib.pyplot.axis
        The axis we want to draw our plot on.

    data: dictionary
        A dictionary containing the data we want to plot. Keys are the names of the
        data, the items is a list of the values.

        Example:
        data = {
            "x":[1,2,3],
            "y":[1,2,3],
            "z":[1,2,3],
        }

    colors : array-like, optional
        A list of colors which are used for the bars. If None, the colors
        will be the standard matplotlib color cyle. (default: None)

    total_width : float, optional, default: 0.8
        The width of a bar group. 0.8 means that 80% of the x-axis is covered
        by bars and 20% will be spaces between the bars.

    single_width: float, optional, default: 1
        The relative width of a single bar within a group. 1 means the bars
        will touch eachother within a group, values less than 1 will make
        these bars thinner.

    legend: bool, optional, default: True
        If this is set to true, a legend will be added to the axis.
    """

    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][::-1]
        colors = colors[:5] + colors[6:]
    colors = ['darkorange' , 'steelblue', 'plum', 'olivedrab', 'teal', 'steelblue', 'tab:brown']
    
    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = total_width / (n_bars - 2.7)

    # List containing handles for the drawn bars, used for the legend
    bars = []

    if std is None:
        # Iterate over all data
        for i, (name, values) in enumerate(data.items()):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, y in enumerate(values):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', yerr=std)

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])
    else:
        # Iterate over all data
        for i, ((name, values),(std_name, std_values)) in enumerate(zip(data.items(),std.items())):
            # The offset in x direction of that bar
            x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

            # Draw a bar for every value of that type
            for x, (y, std_y) in enumerate(zip(values,std_values)):
                bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)], \
                             edgecolor='black', yerr=std_y, error_kw={'elinewidth': 3, 'barsabove':True})

            # Add a handle to the last drawn bar, which we'll need for the legend
            bars.append(bar[0])

    # Draw legend if we need
    if legend:
        ax.legend(bars, data.keys(), bbox_to_anchor=(1.2,1.5), ncol=6, fancybox=False, fontsize="x-large")

# %%
# BPR
data = {
    "Teacher": [0.3121, 0.3123],
    "Student": [0.2421, 0.2701],
    "DE":    [0.2542, 0.2807],
    "HTD": [0.2635, 0.2909]
}

std = {
    "Teacher": [2.7e-3, 1.4e-3],
    "Student": [1.7e-3, 2.1e-3],
    "DE":    [1.5e-3, 2.5e-3],
    "HTD": [1.2e-3, 2.2e-3]
}

data = data
fig, ax = plt.subplots(figsize=(5,3))
bar_plot(ax, data, total_width=0.25, single_width=1.0, legend=False, std=std)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.2*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'linear'
labels[3] = 'non-linear'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=21)
plt.tick_params(axis="y", labelsize=21)
plt.locator_params(axis='y', nbins=6)
#plt.xlabel('$\phi$', fontsize=20)
plt.ylabel('Recall@10', fontsize=21)
plt.title('Tag Retrival', fontsize=21)

plt.show()
# fig.savefig("KLD_LG3.pdf", bbox_inches="tight")

# %%
# LGCN
data = {
    "Teacher": [0.3489, 0.3360],
    "Student": [0.2523, 0.2971],
    "DE":    [0.2565, 0.3053],
    "HTD": [0.2650, 0.3138]
}

std = {
    "Teacher": [0.6e-3, 1.2e-3],
    "Student": [0.7e-3, 0.3e-3],
    "DE":    [1.2e-3, 1.3e-3],
    "HTD": [0.3e-3, 1.1e-3]
}

data = data
fig, ax = plt.subplots(figsize=(5,3))
bar_plot(ax, data, total_width=0.25, single_width=1.0, legend=False, std=std)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.2*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'linear'
labels[3] = 'non-linear'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=21)
plt.tick_params(axis="y", labelsize=21)
plt.locator_params(axis='y', nbins=6)
#plt.xlabel('$\phi$', fontsize=20)
plt.ylabel('Recall@10', fontsize=21)
plt.title('Tag Retrival', fontsize=21)

plt.show()
# fig.savefig("KLD_LG3.pdf", bbox_inches="tight")

# %%
# BPR
data = {
    "Teacher": [0.6531, 0.6357],
    "Student": [0.4222, 0.4224],
    "DE":    [0.5448, 0.5123],
    "HTD": [0.5653, 0.5318]
}

std = {
    "Teacher": [2.5e-3, 8.8e-3],
    "Student": [7.4e-3, 7.9e-3],
    "DE":    [3.2e-3, 6.6e-3],
    "HTD": [5.0e-3, 3.5e-3]
}

data = data
fig, ax = plt.subplots(figsize=(5,3))
bar_plot(ax, data, total_width=0.25, single_width=1.0, legend=False, std=std)

low = min(min(list(data.values())))
high = max(max(list(data.values())))

y_low = low-0.1*(high-low)
y_high = high+0.2*(high-low)

plt.ylim([y_low, y_high])
#plt.axhline(y=teacher_y, color='r', linestyle='--')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'linear'
labels[3] = 'non-linear'

ax.set_xticklabels(labels)
plt.tick_params(axis="x", labelsize=21)
plt.tick_params(axis="y", labelsize=21)
plt.locator_params(axis='y', nbins=6)
#plt.xlabel('$\phi$', fontsize=20)
plt.ylabel('Recall@10', fontsize=21)
plt.title('Tag Retrival', fontsize=21)

plt.show()
# fig.savefig("KLD_LG3.pdf", bbox_inches="tight")
